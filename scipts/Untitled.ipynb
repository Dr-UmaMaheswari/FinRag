# %%
from pymilvus import connections, utility

connections.connect("default", host="127.0.0.1", port="19530")
print(utility.list_collections())
# Out:
# ['boi_bank_policy_chunks', 'central_bank_policy_chunks', 'cub_bank_policy_chunks', 'hpscb_bank_policy_chunks', 'idbi_policy_chunks', 'generic_policy_chunks', 'maharastra_bank_policy_chunks', 'bank_of_barado_bank_policy_chunks', 'dcb_bank_policy_chunks', 'hdfc_bank_policy_chunks', 'idfc_policy_chunks', 'kodak_bank_policy_chunks', 'kvb_bank_policy_chunks', 'mcb_bank_policy_chunks', 'punjab_bank_policy_chunks', 'axis_bank_policy_chunks', 'canara_bank_policy_chunks', 'csb_bank_policy_chunks', 'indian_bank_policy_chunks', 'rbi_faq_chunks', 'cscm_bank_policy_chunks', 'icici_bank_policy_chunks', 'npci_bank_policy_chunks', 'tmb_policy_chunks', 'uco_policy_chunks', 'union_policy_chunks', 'yes_bank_policy_chunks']

# %%
from pymilvus import connections, Collection

connections.connect("default", host="127.0.0.1", port="19530")

for name in ["axis_bank_policy_chunks","canara_bank_policy_chunks","boi_bank_policy_chunks"]:
    col = Collection(name)
    print(name, col.num_entities)
# Out:
# axis_bank_policy_chunks 29
# canara_bank_policy_chunks 77
# boi_bank_policy_chunks 34
